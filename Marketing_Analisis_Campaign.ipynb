# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# %%
df = pd.read_csv('marketing_campaign.csv')
df
# Out:
#         Campaign_ID              Company Campaign_Type Target_Audience  \
# 0                 1  Innovate Industries         Email       Men 18-24
# 1                 2       NexGen Systems         Email     Women 35-44
# 2                 3    Alpha Innovations    Influencer       Men 25-34
# 3                 4   DataTech Solutions       Display        All Ages
# 4                 5       NexGen Systems         Email       Men 25-34
# ...             ...                  ...           ...             ...
# 199995       199996             TechCorp       Display        All Ages
# 199996       199997   DataTech Solutions         Email       Men 25-34
# 199997       199998   DataTech Solutions  Social Media       Men 18-24
# 199998       199999  Innovate Industries    Influencer        All Ages
# 199999       200000  Innovate Industries  Social Media     Women 35-44
#
#        Duration Channel_Used  Conversion_Rate Acquisition_Cost   ROI  \
# ...

# %% [markdown]
# ## Data Understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Campaign_ID       200000 non-null  int64
#  1   Company           200000 non-null  object
#  2   Campaign_Type     200000 non-null  object
#  3   Target_Audience   200000 non-null  object
#  4   Duration          200000 non-null  object
#  5   Channel_Used      200000 non-null  object
#  6   Conversion_Rate   200000 non-null  float64
#  7   Acquisition_Cost  200000 non-null  object
#  8   ROI               200000 non-null  float64
#  9   Location          200000 non-null  object
#  10  Language          200000 non-null  object
#  11  Clicks            200000 non-null  int64
#  12  Impressions       200000 non-null  int64
#  13  Engagement_Score  200000 non-null  int64
#  14  Customer_Segment  200000 non-null  object
#  15  Date              200000 non-null  object
# ...

# %%
df.shape
# Out:
# (200000, 16)

# %%
df.isnull().sum()
# Out:
# Campaign_ID         0
# Company             0
# Campaign_Type       0
# Target_Audience     0
# Duration            0
# Channel_Used        0
# Conversion_Rate     0
# Acquisition_Cost    0
# ROI                 0
# Location            0
# Language            0
# Clicks              0
# Impressions         0
# Engagement_Score    0
# Customer_Segment    0
# Date                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          Campaign_ID  Conversion_Rate            ROI         Clicks  \
# count  200000.000000    200000.000000  200000.000000  200000.000000
# mean   100000.500000         0.080070       5.002438     549.772030
# std     57735.171256         0.040602       1.734488     260.019056
# min         1.000000         0.010000       2.000000     100.000000
# 25%     50000.750000         0.050000       3.500000     325.000000
# 50%    100000.500000         0.080000       5.010000     550.000000
# 75%    150000.250000         0.120000       6.510000     775.000000
# max    200000.000000         0.150000       8.000000    1000.000000
#
#          Impressions  Engagement_Score
# count  200000.000000     200000.000000
# mean     5507.301520          5.494710
# std      2596.864286          2.872581
# min      1000.000000          1.000000
# 25%      3266.000000          3.000000
# 50%      5517.500000          5.000000
# 75%      7753.000000          8.000000
# ...

# %%
# Memfilter data untuk perusahaan "DataTech Solutions"
df_datatech = df[df['Company'] == 'DataTech Solutions']

# Menampilkan 5 baris pertama dari data yang sudah difilter
print("Data untuk perusahaan DataTech Solutions:")
df_datatech.head()

# Menampilkan informasi dasar tentang data
print("\nInfo dataset:")
df_datatech.info()

# Menampilkan statistik deskriptif
print("\nStatistik deskriptif:")
df_datatech.describe()
# Out:
# Data untuk perusahaan DataTech Solutions:
#
# Info dataset:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40012 entries, 3 to 199997
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       40012 non-null  int64
#  1   Company           40012 non-null  object
#  2   Campaign_Type     40012 non-null  object
#  3   Target_Audience   40012 non-null  object
#  4   Duration          40012 non-null  object
#  5   Channel_Used      40012 non-null  object
#  6   Conversion_Rate   40012 non-null  float64
#  7   Acquisition_Cost  40012 non-null  object
#  8   ROI               40012 non-null  float64
#  9   Location          40012 non-null  object
#  10  Language          40012 non-null  object
#  11  Clicks            40012 non-null  int64
#  12  Impressions       40012 non-null  int64
#  13  Engagement_Score  40012 non-null  int64
#  14  Customer_Segment  40012 non-null  object
# ...

# %%
df_datatech.to_csv('marketing_campaign_dt_solutions.csv', index=False)
print(f"Dataset telah disimpan")

# Verifikasi bahwa file telah disimpan dengan membaca ulang
df_saved = pd.read_csv('marketing_campaign_dt_solutions.csv')
df_saved.head()
# Out:
# Dataset telah disimpan
#    Campaign_ID             Company Campaign_Type Target_Audience Duration  \
# 0            4  DataTech Solutions       Display        All Ages  60 days
# 1            6  DataTech Solutions       Display        All Ages  15 days
# 2            8  DataTech Solutions        Search       Men 18-24  45 days
# 3           20  DataTech Solutions    Influencer       Men 25-34  15 days
# 4           21  DataTech Solutions        Search     Women 25-34  15 days
#
#   Channel_Used  Conversion_Rate Acquisition_Cost   ROI     Location  Language  \
# 0      YouTube             0.11       $12,724.00  5.55        Miami  Mandarin
# 1    Instagram             0.07        $9,716.00  4.36     New York    German
# 2   Google Ads             0.08       $13,280.00  5.55  Los Angeles  Mandarin
# 3   Google Ads             0.09       $10,258.00  3.83        Miami    French
# 4        Email             0.04       $16,580.00  7.99     New York   Spanish
#
# ...

# %%
# Fungsi untuk mendeteksi outlier menggunakan metode IQR
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)  # Kuartil pertama (25%)
    Q3 = df[column].quantile(0.75)  # Kuartil ketiga (75%)
    IQR = Q3 - Q1  # Interquartile Range
    lower_bound = Q1 - 1.5 * IQR  # Batas bawah
    upper_bound = Q3 + 1.5 * IQR  # Batas atas

    # Menemukan outlier
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    return outliers, lower_bound, upper_bound

# Kolom numerik yang akan diperiksa untuk outlier
numeric_columns = ['ROI', 'Clicks', 'Impressions', 'Engagement_Score']

# Pemeriksaan outlier untuk setiap kolom numerik
for column in numeric_columns:
    outliers, lower_bound, upper_bound = detect_outliers(df, column)
    print(f"\nPemeriksaan outlier untuk kolom: {column}")
    print(f"Batas bawah: {lower_bound:.2f}, Batas atas: {upper_bound:.2f}")
    print(f"Jumlah outlier: {len(outliers)}")
    if len(outliers) > 0:
        print("Data outlier:")
        print(outliers[[column, 'Campaign_ID', 'Channel_Used', 'Customer_Segment']])
    else:
        print("Tidak ada outlier ditemukan.")
# Out:
# Pemeriksaan outlier untuk kolom: ROI
# Batas bawah: -1.01, Batas atas: 11.02
# Jumlah outlier: 0
# Tidak ada outlier ditemukan.
#
# Pemeriksaan outlier untuk kolom: Clicks
# Batas bawah: -350.00, Batas atas: 1450.00
# Jumlah outlier: 0
# Tidak ada outlier ditemukan.
#
# Pemeriksaan outlier untuk kolom: Impressions
# Batas bawah: -3464.50, Batas atas: 14483.50
# Jumlah outlier: 0
# Tidak ada outlier ditemukan.
#
# Pemeriksaan outlier untuk kolom: Engagement_Score
# Batas bawah: -4.50, Batas atas: 15.50
# Jumlah outlier: 0
# Tidak ada outlier ditemukan.
